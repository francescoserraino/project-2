# %% [markdown]
# # SQL Project
# You were hired by Ironhack to perform an Analytics Consulting Project entitled: competitive landscape.
#
# Your mission is to create and populate an appropriate database with many coding schools that are our competition, as well as design an suitable queries that answer business questions of interest (to be defined by you)

# %% [markdown]
# **Suggested Steps in the Project:**
#
#
# *   Read this notebook and understand each function. Comment the code appropriately
#
# *   Populate the list of schools with a wider variety of schools (how are you going to get the school ID?)
#
# * Take a look at the obtained dataframes. What dimensions do you have? what keys do you have? how could the different dataframes be connected?
#
# * Go back to the drawing board and try to create an entity relationship diagram for tables available
#
# * Once you have the schemas you want, you will need to:
#   - create the suitable SQL queries to create the tables and populate them
#   - run these queries using the appropriate Python connectors
#
# * Bonus: How will this datamodel be updated in the future? Please write auxiliary functions that test the database for data quality issues. For example: how could you make sure you only include the most recent comments when you re-run the script?
#
#
# # Suggested Deliverables
#
# * 5-6 minute presentation of data model created, decision process and business analysis proposed
#
# * exported .sql file with the final schema
#
# * Supporting python files used to generate all logic
#
# * High level documentation explaining tables designed and focusing on update methods
#
# Crucial hint: check out the following tutorial:
# https://www.dataquest.io/blog/sql-insert-tutorial/

# %%
# you must populate this dict with the schools required -> try talking to the teaching team about this


schools = {   
'ironhack' : 10828,
'app-academy' : 10525,
'springboard' : 11035,
'Udacity': 11118    
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    #makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    #converts json to dataframe
    reviews =  pd.DataFrame(data['content']['reviews'])
  
    #aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('',x)
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    reviews['school'] = school
    return reviews

# %%
# could you write this as a list comprehension? ;)
comments = []

for school in schools.keys():
    print(school)
    comments.append(get_comments_school(school))

comments = pd.concat(comments)
# Out:
# ironhack
# app-academy
# springboard
# Udacity

# %%
comments
# Out:
#           id           name  anonymous hostProgramName  graduatingYear  \
# 0     269512      Anonymous       True            None          2019.0
# 1     269343         Felipe      False            None          2020.0
# 2     269201   Ozzie Zamora      False            None          2020.0
# 3     269141    Sacha Dollé      False            None          2020.0
# 4     269133  Calypso Redor      False            None          2020.0
# ...      ...            ...        ...             ...             ...
# 1170  239461    Phil anonio      False            None          2017.0
# 1171  236598      Anonymous       True            None          2017.0
# 1172  233529      Anonymous      False            None          2016.0
# 1173  233782      Anonymous      False    Data Science          2016.0
# 1174  233333      Anonymous      False            None          2016.0
#
#       isAlumni              jobTitle  \
# 0        False  Full stack developer
# 1        False            Unemployed
# 2        False           UI Designer
# 3        False          Data Analyst
# 4        False      Product Designer
# ...        ...                   ...
# 1170      True                  None
# 1171      True                  None
# 1172      True                  None
# 1173      True                  None
# 1174     False                  None
#
#                                                 tagline  \
# 0     Great qualified teachers but unorganized, not ...
# 1     UX UI Iron Hack Sao Paulo, be careful before y...
# 2                        UX/UI Design Part-Time | Miami
# 3            Great bootcamp, great team, great learning
# 4                                Une superbe expérience
# ...                                                 ...
# 1170                                         Worst ever
# 1171                             Introduction to Python
# 1172                                    Can be improved
# 1173                              Intro to data science
# 1174                                       Not great...
#
#                                                    body   createdAt  \
# 0     <span class="truncatable"><p></p><p>I attended...  10/20/2020
# 1     <span class="truncatable"><p>(Por favor copie ...  10/13/2020
# 2     <span class="truncatable"><p>A truly amazing e...   10/7/2020
# 3     <span class="truncatable"><p>I use to work in ...   10/6/2020
# 4     <span class="truncatable"><p></p><p>« On m’ava...   10/6/2020
# ...                                                 ...         ...
# 1170  <p>They are thieves. DO NOT pay them. I made a...   11/9/2017
# 1171  <span class="truncatable"><p>Pros: (1) self-pa...   6/26/2017
# 1172  <span class="truncatable"><p>There's a lot of ...  12/22/2016
# 1173  <span class="truncatable"><p>I love Udacity. I...   5/13/2016
# 1174  <span class="truncatable"><p>Support is very l...   2/28/2016
#
#        queryDate                    program             user overallScore  \
# 0     2020-10-20                             {'image': None}          2.7
# 1     2020-10-13      UX/UI Design Bootcamp  {'image': None}          3.3
# 2     2020-10-07     UX/UI Design Part-Time  {'image': None}          5.0
# 3     2020-10-06    Data Analytics Bootcamp  {'image': None}          5.0
# 4     2020-10-06                             {'image': None}          5.0
# ...          ...                        ...              ...          ...
# 1170  2017-11-09                       None  {'image': None}          1.0
# 1171  2017-06-26  Intro to Computer Science  {'image': None}          3.0
# 1172  2016-12-22                       None  {'image': None}          3.0
# 1173  2016-05-13  Intro to Computer Science  {'image': None}          5.0
# 1174  2016-02-28                       None  {'image': None}          2.0
#
#      comments overall curriculum jobSupport  \
# 0          []     3.0        4.0        1.0
# 1          []     2.0        5.0        3.0
# 2          []     5.0        5.0        5.0
# 3          []     5.0        5.0        5.0
# 4          []     5.0        5.0        5.0
# ...       ...     ...        ...        ...
# 1170       []     1.0        1.0        1.0
# 1171       []     3.0        4.0        2.0
# 1172       []     3.0        3.0        3.0
# 1173       []     5.0        NaN        NaN
# 1174       []     2.0        NaN        NaN
#
#                                             review_body    school
# 0     I attended the Berlin bootcamp and the biggest...  ironhack
# 1     (Por favor copie e cole no google tradutor se ...  ironhack
# 2     A truly amazing experience, to be honest. I wa...  ironhack
# 3     I use to work in advertisement and decided to ...  ironhack
# 4     « On m’avait prévenu de ce que voulait dire « ...  ironhack
# ...                                                 ...       ...
# 1170  They are thieves. DO NOT pay them. I made a mi...   Udacity
# 1171  Pros: (1) self-paced, (2) context-based, (3) c...   Udacity
# 1172  There's a lot of positives about the Udacity f...   Udacity
# 1173  I love Udacity. I watch many free online cours...   Udacity
# 1174  Support is very limited. Don't think that it's...   Udacity
#
# [3817 rows x 20 columns]

# %%
from pandas.io.json import json_normalize

def get_school_info(school, school_id):
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F'+ str(school) + '&isDataTarget=false&bootcampId='+ str(school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns= ['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])
    
    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website,description,logoUrl]).T
    school_df.columns =  ['website','description','LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school
    

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df

locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a,b,c,d = get_school_info(school,id)
    
    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)
# Out:
# ironhack
# <ipython-input-4-7111c633f1e2>:14: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   locations_df = json_normalize(locations)
# app-academy
# springboard
# Udacity

# %%
locations_list
# Out:
# [      id               description  country.id   country.name country.abbrev  \
#  0  15901           Berlin, Germany        57.0        Germany             DE
#  1  16022       Mexico City, Mexico        29.0         Mexico             MX
#  2  16086    Amsterdam, Netherlands        59.0    Netherlands             NL
#  3  16088         Sao Paulo, Brazil        42.0         Brazil             BR
#  4  16109             Paris, France        38.0         France             FR
#  5  16375  Miami, FL, United States         1.0  United States             US
#  6  16376             Madrid, Spain        12.0          Spain             ES
#  7  16377          Barcelona, Spain        12.0          Spain             ES
#  8  16709          Lisbon, Portugal        28.0       Portugal             PT
#  9  17233                    Online         NaN            NaN            NaN
#
#     city.id    city.name city.keyword  state.id state.name state.abbrev  \
#  0  31156.0       Berlin       berlin       NaN        NaN          NaN
#  1  31175.0  Mexico City  mexico-city       NaN        NaN          NaN
#  2  31168.0    Amsterdam    amsterdam       NaN        NaN          NaN
#  3  31121.0    Sao Paulo    sao-paulo       NaN        NaN          NaN
#  4  31136.0        Paris        paris       NaN        NaN          NaN
#  5     31.0        Miami        miami      11.0    Florida           FL
#  6  31052.0       Madrid       madrid       NaN        NaN          NaN
#  7  31170.0    Barcelona    barcelona       NaN        NaN          NaN
#  8  31075.0       Lisbon       lisbon       NaN        NaN          NaN
#  9      NaN          NaN          NaN       1.0     Online       Online
#
#    state.keyword    school  school_id
#  0           NaN  ironhack      10828
#  1           NaN  ironhack      10828
#  2           NaN  ironhack      10828
#  3           NaN  ironhack      10828
#  4           NaN  ironhack      10828
#  5       florida  ironhack      10828
#  6           NaN  ironhack      10828
#  7           NaN  ironhack      10828
#  8           NaN  ironhack      10828
#  9        online  ironhack      10828  ,
#        id                       description  country.id   country.name  \
#  0  15704  San Francisco, CA, United States         1.0  United States
#  1  15705  New York City, NY, United States         1.0  United States
#  2  15862                            Online         NaN            NaN
#
#    country.abbrev  state.id  state.name state.abbrev state.keyword  city.id  \
#  0             US         6  California           CA    california     13.0
#  1             US        34    New York           NY      new-york   1507.0
#  2            NaN         1      Online       Online        online      NaN
#
#         city.name   city.keyword       school  school_id
#  0  San Francisco  san-francisco  app-academy      10525
#  1            NYC  new-york-city  app-academy      10525
#  2            NaN            NaN  app-academy      10525  ,
#        id description  state.id state.name state.abbrev state.keyword  \
#  0  16013      Online         1     Online       Online        online
#
#          school  school_id
#  0  springboard      11035  ,
#        id description  state.id state.name state.abbrev state.keyword   school  \
#  0  15807      Online         1     Online       Online        online  Udacity
#
#     school_id
#  0      11118  ]

# %%
locations = pd.concat(locations_list)
locations
# Out:
#       id                       description  country.id   country.name  \
# 0  15901                   Berlin, Germany        57.0        Germany
# 1  16022               Mexico City, Mexico        29.0         Mexico
# 2  16086            Amsterdam, Netherlands        59.0    Netherlands
# 3  16088                 Sao Paulo, Brazil        42.0         Brazil
# 4  16109                     Paris, France        38.0         France
# 5  16375          Miami, FL, United States         1.0  United States
# 6  16376                     Madrid, Spain        12.0          Spain
# 7  16377                  Barcelona, Spain        12.0          Spain
# 8  16709                  Lisbon, Portugal        28.0       Portugal
# 9  17233                            Online         NaN            NaN
# 0  15704  San Francisco, CA, United States         1.0  United States
# 1  15705  New York City, NY, United States         1.0  United States
# 2  15862                            Online         NaN            NaN
# 0  16013                            Online         NaN            NaN
# 0  15807                            Online         NaN            NaN
#
#   country.abbrev  city.id      city.name   city.keyword  state.id  state.name  \
# 0             DE  31156.0         Berlin         berlin       NaN         NaN
# 1             MX  31175.0    Mexico City    mexico-city       NaN         NaN
# 2             NL  31168.0      Amsterdam      amsterdam       NaN         NaN
# 3             BR  31121.0      Sao Paulo      sao-paulo       NaN         NaN
# 4             FR  31136.0          Paris          paris       NaN         NaN
# 5             US     31.0          Miami          miami      11.0     Florida
# 6             ES  31052.0         Madrid         madrid       NaN         NaN
# 7             ES  31170.0      Barcelona      barcelona       NaN         NaN
# 8             PT  31075.0         Lisbon         lisbon       NaN         NaN
# 9            NaN      NaN            NaN            NaN       1.0      Online
# 0             US     13.0  San Francisco  san-francisco       6.0  California
# 1             US   1507.0            NYC  new-york-city      34.0    New York
# 2            NaN      NaN            NaN            NaN       1.0      Online
# 0            NaN      NaN            NaN            NaN       1.0      Online
# 0            NaN      NaN            NaN            NaN       1.0      Online
#
#   state.abbrev state.keyword       school  school_id
# 0          NaN           NaN     ironhack      10828
# 1          NaN           NaN     ironhack      10828
# 2          NaN           NaN     ironhack      10828
# 3          NaN           NaN     ironhack      10828
# 4          NaN           NaN     ironhack      10828
# 5           FL       florida     ironhack      10828
# 6          NaN           NaN     ironhack      10828
# 7          NaN           NaN     ironhack      10828
# 8          NaN           NaN     ironhack      10828
# 9       Online        online     ironhack      10828
# 0           CA    california  app-academy      10525
# 1           NY      new-york  app-academy      10525
# 2       Online        online  app-academy      10525
# 0       Online        online  springboard      11035
# 0       Online        online      Udacity      11118

# %%
courses = pd.concat(courses_list)
courses.head(30)
# Out:
#                                           courses       school  school_id
# 0                         Data Analytics Bootcamp     ironhack      10828
# 1                        Data Analytics Part-Time     ironhack      10828
# 2                           UX/UI Design Bootcamp     ironhack      10828
# 3                          UX/UI Design Part-Time     ironhack      10828
# 4                        Web Development Bootcamp     ironhack      10828
# 5                       Web Development Part-Time     ironhack      10828
# 6                         Cyber Security Bootcamp     ironhack      10828
# 0                                   Bootcamp Prep  app-academy      10525
# 1              Software Engineer Track: In-Person  app-academy      10525
# 2                 Software Engineer Track: Online  app-academy      10525
# 0                     Data Analytics Career Track  springboard      11035
# 1                   Data Engineering Career Track  springboard      11035
# 2                       Data Science Career Track  springboard      11035
# 3                  Data Science Career Track Prep  springboard      11035
# 4                  Digital Marketing Career Track  springboard      11035
# 5                   Introduction to Cybersecurity  springboard      11035
# 6                          Introduction to Design  springboard      11035
# 7       Machine Learning Engineering Career Track  springboard      11035
# 8               Software Engineering Career Track  springboard      11035
# 9   Software Engineering Career Track Prep Course  springboard      11035
# 10                      UI/UX Design Career Track  springboard      11035
# 11                                UX Career Track  springboard      11035
# 0                      AI Programming with Python      Udacity      11118
# 1                              Al Product Manager      Udacity      11118
# 2                                  Android Basics      Udacity      11118
# 3                               Android Developer      Udacity      11118
# 4                         Artificial Intelligence      Udacity      11118
# 5             Artificial Intelligence for Trading      Udacity      11118
# 6                            Blockchain Developer      Udacity      11118
# 7                              Business Analytics      Udacity      11118

# %%
badges = pd.concat(badges_list)
badges.head()
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1   Flexible Classes   flexible_classes
#
#                                          description       school  school_id
# 0          <p>School offers fully online courses</p>     ironhack      10828
# 1  <p>School publishes a third-party verified out...     ironhack      10828
# 2  <p>School offers part-time and evening classes...     ironhack      10828
# 0          <p>School offers fully online courses</p>  app-academy      10525
# 1  <p>School offers part-time and evening classes...  app-academy      10525

# %%
# any data cleaning still missing here? take a look at the description
schools = pd.concat(schools_list)
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0  www.springboard.com/?utm_source=switchup&utm_m...
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Springboard is an...
# 0  <span class="truncatable"><p>Udacity is a glob...
#
#                                              LogoUrl       school  school_id
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...     ironhack      10828
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  app-academy      10525
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  springboard      11035
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...      Udacity      11118

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="@ndrewUcles1",
                               db="bootcamps"))

# %%
courses=courses[['courses','school']]
courses.to_sql('courses', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %%
locations_dict={'city.name':'city_name','country.name':'country_name','id':'loc_id'}
locations.rename(columns=locations_dict, inplace=True)

locations=locations[['school','city_name','country_name','loc_id']]
locations.to_sql('locations', con = engine, if_exists = 'append', chunksize = 1000,index=False)
locations
# Out:
#         school      city_name   country_name  loc_id
# 0     ironhack         Berlin        Germany   15901
# 1     ironhack    Mexico City         Mexico   16022
# 2     ironhack      Amsterdam    Netherlands   16086
# 3     ironhack      Sao Paulo         Brazil   16088
# 4     ironhack          Paris         France   16109
# 5     ironhack          Miami  United States   16375
# 6     ironhack         Madrid          Spain   16376
# 7     ironhack      Barcelona          Spain   16377
# 8     ironhack         Lisbon       Portugal   16709
# 9     ironhack            NaN            NaN   17233
# 0  app-academy  San Francisco  United States   15704
# 1  app-academy            NYC  United States   15705
# 2  app-academy            NaN            NaN   15862
# 0  springboard            NaN            NaN   16013
# 0      Udacity            NaN            NaN   15807

# %%
comment_dict = {
'jobSupport':'job_support',
'overall':'overall_rating',
'overallScore':'average_rating',
'queryDate':'query_date',
'jobTitle': 'job_title',
'isAlumni': 'is_alumni',
'graduatingYear':'graduating_year',
'id': 'com_id'}

comments.rename( columns = comment_dict, inplace = True)

comments=comments[['school','job_support','curriculum','overall_rating','average_rating','program','query_date','job_title','is_alumni','graduating_year','com_id']]
comments.to_sql('reviews', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %%
countries_info = pd.read_excel(r'countries_data.xlsx')
countries_info['percentage_growth'] = countries_info['2019']-countries_info['2015']

# %%
countries_info_dict = {
'GEO (Labels)':'Country'}
countries_info.rename( columns = countries_info_dict, inplace = True)
countries_info.to_sql('countries_info', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %%
#large_growth = countries_info[countries_info['2019']-countries_info['2015'] > 0.5 ]
#large_growth

# %%
quality_of_life = pd.read_excel(r'quality_of_life.xlsx')

# %%
quality_of_life.to_sql('quality_of_life', con = engine, if_exists = 'append', chunksize = 1000, index=False)

# %%
import pymysql

# %%
connection=pymysql.connect(host='localhost',user='root',password='@ndrewUcles1', db='bootcamps')

my_cursor = connection.cursor()

# %%
query1='create table locations_numbers as select locations.school, round(avg(overall_rating),2) as average_rating, count(distinct locations.loc_id)-1 as no_of_locations from locations left join reviews on locations.school = reviews.school group by locations.school, reviews.school order by avg(overall_rating) desc;'

query2="create table courses_by_ratings as SELECT   CASE     WHEN program LIKE '%Data%'   THEN 'Data Analytics/Science'     WHEN program LIKE '%Web%' THEN 'Web Design/Developmet'     WHEN program LIKE '%UX%' THEN 'UX/UI Design'     when program like '%Software%' then 'Software Engineering'     when program like '%Cyber%' then 'Cyber Security'     when program like '%Blockchain%' then 'Blockchain'   END AS program , round(avg(overall_rating),2) AS average_rating FROM reviews GROUP BY    CASE     WHEN program LIKE '%Data%'   THEN 'Data Analytics/Science'     WHEN program LIKE '%Web%' THEN 'Web Design/Developmet'     WHEN program LIKE '%UX%' THEN 'UX/UI Design'     when program like '%Software%' then 'Software Engineering'     when program like '%Cyber%' then 'Cyber Security'     when program like '%Blockchain%' then 'Blockchain'   END order by average_rating desc;"

query3="create table top_15_cities as select City from quality_of_life inner join countries_info on quality_of_life.Country = countries_info.Country group by quality_of_life.City order by round(avg(countries_info.percentage_growth),2) desc, round(avg(quality_of_life.Ranking),2) asc limit 15;"

# %%
my_cursor.execute(query1)
# Out:
# 4

# %%
my_cursor.execute(query2)
# Out:
# 6

# %%
my_cursor.execute(query3)
# Out:
# 15

# %%
locations_numbers = pd.read_sql_table('locations_numbers', engine) 
courses_by_ratings = pd.read_sql_table('courses_by_ratings', engine)
top_15_cities = pd.read_sql_table('top_15_cities', engine)

# %%
top_15_cities
# Out:
#           City
# 0     Budapest
# 1      Vilnius
# 2       Zagreb
# 3       Zürich
# 4       Geneva
# 5        Basel
# 6         Bern
# 7     Brussels
# 8      Tallinn
# 9       Athens
# 10    Belgrade
# 11   Stockholm
# 12      Lisbon
# 13   Amsterdam
# 14  Luxembourg

# %%
courses_by_ratings.dropna(axis = 0, inplace = True)
courses_by_ratings
# Out:
#                   program  average_rating
# 0          Cyber Security            5.00
# 1   Web Design/Developmet            4.87
# 2            UX/UI Design            4.77
# 3    Software Engineering            4.68
# 5  Data Analytics/Science            4.50

# %%
locations_numbers
# Out:
#         school  average_rating  no_of_locations
# 0     ironhack            4.89                9
# 1  app-academy            4.69                2
# 2  springboard            4.59                0
# 3      Udacity            4.55                0

# %%
#locations_numbers ['no_of_locations'] = locations_numbers ['no_of_locations'].replace(0, 'Only online')

# %%
correlation_coefficient = locations_numbers['average_rating'].corr(locations_numbers['no_of_locations'])
correlation_coefficient
# Out:
# 0.9812694051711026

# %%
countries_info_top = countries_info[countries_info['percentage_growth']>countries_info['percentage_growth'].quantile(0.8)]
countries_info_top.set_index('Country', inplace = True)
countries_info_top.drop('percentage_growth',axis='columns', inplace=True)
countries_info_top = countries_info_top.transpose()
# Out:
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
import matplotlib.pyplot as plt
lines = (countries_info_top/countries_info_top.iloc[0]*100).plot.line(figsize = (15,6))
plt.xlabel("Year")
plt.ylabel("Normalized Percentage of Jobs in Tech")
plt.title('Yearly Growth of Employability in Tech by Country')
# Out:
# Text(0.5, 1.0, 'Yearly Growth of Employability in Tech by Country')
